# %%
pip install pyreadstat
# Out:
# ...
#
# ...

# %% [markdown]
# ## PARTE 1: ANÁLISIS DE LA BASE DE HOGARES Y TIPO DE OCUPACIÓN

# %% [markdown]
# ### EJERCICO 2
# Descarguen la base de microdatos de la EPH correspondiente al primer
# trimestre de 2004 y 2024 e  formato .dta y .xls, respectivamente. L
# base de hogares se llama Hogar_t104.dta y usu_hogar_T124.xl ,
# respectivamente. Eliminen todas las observaciones que no correspon en
# a los aglomerados de Ciudad Autónoma de Buenos Aires o Gran Bu nos
# Aires y unan ambos trimestres en una sola base. Esto es, a la base  e la
# encuesta individual de cada año (que usaron en el TP3) unan la b se de
# la encuesta de hogar. Asegúrese de estar usando las va iables
# CODUSU y NRO_Hogar para el merge.

# %%
import pandas as pd 
import pyreadstat

#CARGA BASE DE DATOS HOGAR 2024
path_file_XLS = "C:/Users/belug/Downloads/usu_hogar_T124.xlsx"
df2024_hogar = pd.read_excel(path_file_XLS)
df2024_hogar
# Out:
#                               CODUSU  ANO4  TRIMESTRE  NRO_HOGAR  REALIZADA  \
# 0      TQRMNORPSHLOLMCDEFNFF00852337  2024          1          1          1
# 1      TQRMNOPRYHKOKTCDEFNFF00856789  2024          1          1          1
# 2      TQTMNORRSHKOKTCDEFNFF00856790  2024          1          1          1
# 3      TQRMNORRSHKOKTCDEFNFF00856791  2024          1          1          1
# 4      TQRMNOQTVHKLLLCDEFNFF00856792  2024          1          1          1
# ...                              ...   ...        ...        ...        ...
# 16099  TQRMNOPXXHLKKUCDEFNFF00852324  2024          1          1          1
# 16100  TQRMNOPQTHKMLMCDEHMHF00861771  2024          1          1          1
# 16101  TQRMNOSYXHMMLNCDEFNFF00798999  2024          1          1          1
# 16102  TQRMNOPTSHLOLQCDEFNFF00852331  2024          1          1          1
# 16103  TQRMNOVRSHKOKMCDEFOCD00861772  2024          1          1          1
#
# ...

# %%
#CARGA BASE DE DATOS HOGAR 2004

path_file_DTA = "C:/Users/belug/Downloads/Hogar_t104.dta"

df2004_hogar, meta2004 = pyreadstat.read_dta(path_file_DTA)
display(df2004_hogar)
# Out:
#        CODUSU  nro_hogar  realizada    ano4  trimestre  region mas_500  \
# 0      125051        1.0        1.0  2004.0        1.0    43.0       S
# 1      125082        1.0        1.0  2004.0        1.0    43.0       S
# 2      125181        1.0        1.0  2004.0        1.0    43.0       S
# 3      125283        1.0        1.0  2004.0        1.0    43.0       S
# 4      126192        1.0        1.0  2004.0        1.0    43.0       S
# ...       ...        ...        ...     ...        ...     ...     ...
# 12811  283186        1.0        1.0  2004.0        1.0    43.0       N
# 12812  284685        1.0        1.0  2004.0        1.0    43.0       N
# 12813  285584        1.0        1.0  2004.0        1.0    43.0       N
# 12814  287302        2.0        1.0  2004.0        1.0    43.0       N
# 12815  288189        1.0        1.0  2004.0        1.0    43.0       N
#
#        aglomerado  pondera  iv1  ... gdeccfr  pdeccfr  adeccfr vii1_1  vii1_2  \
# ...

# %%
#FILTRADO BSAS PARA 2024

# Filtrar los valores de Aglomerado 32 y 33
df2024_h = df2024_hogar[df2024_hogar['AGLOMERADO'].isin([32, 33])]

# Mostrar el dataframe filtrado
df2024_h
# Out:
#                               CODUSU  ANO4  TRIMESTRE  NRO_HOGAR  REALIZADA  \
# 5      TQRMNOSPRHLMNNCDEIIAD00854888  2024          1          1          1
# 6      TQRMNOSPTHLMNNCDEIIAD00854889  2024          1          1          1
# 7      TQRMNOTXUHKNNPCDEIIAD00856793  2024          1          1          1
# 8      TQRMNOSQVHJLMUCDEIIAD00798163  2024          1          1          1
# 9      TQRMNORXVHJLNNCDEIIAD00798156  2024          1          1          1
# ...                              ...   ...        ...        ...        ...
# 15983  TQRMNOPSSHKMROCDEIJAH00861731  2024          1          1          1
# 15984  TQRMNOPWVHJLSSCDEIJAH00794914  2024          1          1          1
# 15985  TQRMNOQQWHKMOQCDEIJAH00861732  2024          1          1          1
# 15986  TQRMNOSXRHKMNMCDEIJAH00861733  2024          1          1          1
# 15987  TQRMNORRQHMORPCDEIJAH00802469  2024          1          1          1
#
# ...

# %%
#FILTRADO BSAS PARA 2004

# Filtrar los valores de Aglomerado 32 y 33
df2004_h = df2004_hogar[df2004_hogar['aglomerado'].isin([32, 33])]

# Mostrar el dataframe filtrado
df2004_h
# Out:
#        CODUSU  nro_hogar  realizada    ano4  trimestre  region mas_500  \
# 9666   125098        1.0        1.0  2004.0        1.0     1.0       S
# 9667   125397        1.0        1.0  2004.0        1.0     1.0       S
# 9668   125515        1.0        1.0  2004.0        1.0     1.0       S
# 9669   125558        1.0        1.0  2004.0        1.0     1.0       S
# 9670   125599        1.0        1.0  2004.0        1.0     1.0       S
# ...       ...        ...        ...     ...        ...     ...     ...
# 12012  287684        1.0        1.0  2004.0        1.0     1.0       S
# 12013  287810        1.0        1.0  2004.0        1.0     1.0       S
# 12014  287998        1.0        1.0  2004.0        1.0     1.0       S
# 12015  288171        1.0        1.0  2004.0        1.0     1.0       S
# 12016  288405        1.0        1.0  2004.0        1.0     1.0       S
#
#        aglomerado  pondera  iv1  ... gdeccfr  pdeccfr  adeccfr vii1_1  vii1_2  \
# ...

# %%
#BASE DE DATOS HOGAR 2004 - 2024

df2024_h.columns = df2024_h.columns.str.lower()

df_hogar = pd.concat([df2004_h, df2024_h])
display(df_hogar)
# Out:
#        CODUSU  nro_hogar  realizada    ano4  trimestre  region mas_500  \
# 9666   125098        1.0        1.0  2004.0        1.0     1.0       S
# 9667   125397        1.0        1.0  2004.0        1.0     1.0       S
# 9668   125515        1.0        1.0  2004.0        1.0     1.0       S
# 9669   125558        1.0        1.0  2004.0        1.0     1.0       S
# 9670   125599        1.0        1.0  2004.0        1.0     1.0       S
# ...       ...        ...        ...     ...        ...     ...     ...
# 15983     NaN        1.0        1.0  2024.0        1.0     1.0       S
# 15984     NaN        1.0        1.0  2024.0        1.0     1.0       S
# 15985     NaN        1.0        1.0  2024.0        1.0     1.0       S
# 15986     NaN        1.0        1.0  2024.0        1.0     1.0       S
# 15987     NaN        1.0        1.0  2024.0        1.0     1.0       S
#
#        aglomerado  pondera  iv1  ... vii2_1  vii2_2  vii2_3 vii2_4  idimph  \
# ...

# %%
#CARGA BASE DE DATOS 2004 INDIVIDUAL
path_file_XLS = "C:/Users/belug/Downloads/individual2004.xlsx"
dfind_2004 = pd.read_excel(path_file_XLS)
dfind_2004
# Out:
#       Unnamed: 0  CODUSU  nro_hogar  componente  h15  ano4  trimestre  region  \
# 0              0  125098          1           1    1  2004          1       1
# 1              1  125397          1           1    1  2004          1       1
# 2              2  125515          1           1    1  2004          1       1
# 3              3  125558          1           1    1  2004          1       1
# 4              4  125558          1           2    1  2004          1       1
# ...          ...     ...        ...         ...  ...   ...        ...     ...
# 7642        7642  288171          1           3    0  2004          1       1
# 7643        7643  288405          1           1    1  2004          1       1
# 7644        7644  288405          1           2    1  2004          1       1
# 7645        7645  288405          1           3    1  2004          1       1
# 7646        7646  288405          1           4    1  2004          1       1
#
# ...

# %%
#CARGA BASE DE DATOS 2024 INDIVIDUAL
path_file_XLS = "C:/Users/belug/Downloads/individual2024.xlsx"
dfind_2024 = pd.read_excel(path_file_XLS)
dfind_2024
# Out:
#       Unnamed: 0                         codusu  ano4  trimestre  nro_hogar  \
# 0            245  TQRMNOSUWHLKMUCDEIJAH00855260  2024          1          1
# 1            246  TQRMNOSUWHLKMUCDEIJAH00855260  2024          1          1
# 2            247  TQRMNOSUWHLKMUCDEIJAH00855260  2024          1          1
# 3            255  TQSMNORWVHLLKQCDEIJAH00856914  2024          1          1
# 4            256  TQRMNOPQQHLOLRCDEIJAH00855133  2024          1          1
# ...          ...                            ...   ...        ...        ...
# 7046       46045  TQRMNOPUQHKMKNCDEIJAH00861661  2024          1          1
# 7047       46046  TQRMNOPUQHKMKNCDEIJAH00861661  2024          1          1
# 7048       46047  TQRMNOPUQHKMKNCDEIJAH00861661  2024          1          1
# 7049       46048  TQRMNOPUQHKMKNCDEIJAH00861661  2024          1          1
# 7050       46049  TQRMNOPUQHKMKNCDEIJAH00861661  2024          1          1
#
# ...

# %%
#MERGE 2004
df2004_h.loc[:, 'CODUSU'] = df2004_h['CODUSU'].astype(float)

df_merged2004 = pd.merge(df2004_h, dfind_2004, on=['CODUSU', 'nro_hogar'], how='inner')
df_merged2004
# Out:
#         CODUSU  nro_hogar  realizada  ano4_x  trimestre_x  region_x mas_500_x  \
# 0     125098.0        1.0        1.0  2004.0          1.0       1.0         S
# 1     125397.0        1.0        1.0  2004.0          1.0       1.0         S
# 2     125515.0        1.0        1.0  2004.0          1.0       1.0         S
# 3     125558.0        1.0        1.0  2004.0          1.0       1.0         S
# 4     125558.0        1.0        1.0  2004.0          1.0       1.0         S
# ...        ...        ...        ...     ...          ...       ...       ...
# 7642  288171.0        1.0        1.0  2004.0          1.0       1.0         S
# 7643  288405.0        1.0        1.0  2004.0          1.0       1.0         S
# 7644  288405.0        1.0        1.0  2004.0          1.0       1.0         S
# 7645  288405.0        1.0        1.0  2004.0          1.0       1.0         S
# 7646  288405.0        1.0        1.0  2004.0          1.0       1.0         S
#
# ...

# %%
#MERGE 2024
df2024_h
dfind_2024

dfind_2024.rename(columns={'codusu': 'CODUSU'}, inplace=True)
dfind_2024

df2024_h.columns = df2024_h.columns.str.lower()
df2024_h = df2024_h.copy()  # Esto asegura que df2024_h es una copia completa
df2024_h = df2024_h.rename(columns={'codusu': 'CODUSU'})
df2024_h

df_merged2024 = pd.merge(df2024_h, dfind_2024, on=['CODUSU', 'nro_hogar'], how='inner')
df_merged2024
# Out:
#                              CODUSU  ano4_x  trimestre_x  nro_hogar  \
# 0     TQRMNOSPRHLMNNCDEIIAD00854888    2024            1          1
# 1     TQRMNOSPTHLMNNCDEIIAD00854889    2024            1          1
# 2     TQRMNOSPTHLMNNCDEIIAD00854889    2024            1          1
# 3     TQRMNOSPTHLMNNCDEIIAD00854889    2024            1          1
# 4     TQRMNOSPTHLMNNCDEIIAD00854889    2024            1          1
# ...                             ...     ...          ...        ...
# 7046  TQRMNOQQWHKMOQCDEIJAH00861732    2024            1          1
# 7047  TQRMNOSXRHKMNMCDEIJAH00861733    2024            1          1
# 7048  TQRMNORRQHMORPCDEIJAH00802469    2024            1          1
# 7049  TQRMNORRQHMORPCDEIJAH00802469    2024            1          1
# 7050  TQRMNORRQHMORPCDEIJAH00802469    2024            1          1
#
#       realizada  region_x mas_500_x  aglomerado_x  pondera_x  iv1  ...  \
# 0             1         1         S            32       2018    2  ...
# ...

# %%
### MERGE 2004 - 2024
datos = pd.concat([df_merged2004, df_merged2024])
datos
# Out:
#                              CODUSU  nro_hogar  realizada  ano4_x  \
# 0                          125098.0        1.0        1.0  2004.0
# 1                          125397.0        1.0        1.0  2004.0
# 2                          125515.0        1.0        1.0  2004.0
# 3                          125558.0        1.0        1.0  2004.0
# 4                          125558.0        1.0        1.0  2004.0
# ...                             ...        ...        ...     ...
# 7046  TQRMNOQQWHKMOQCDEIJAH00861732        1.0        1.0  2024.0
# 7047  TQRMNOSXRHKMNMCDEIJAH00861733        1.0        1.0  2024.0
# 7048  TQRMNORRQHMORPCDEIJAH00802469        1.0        1.0  2024.0
# 7049  TQRMNORRQHMORPCDEIJAH00802469        1.0        1.0  2024.0
# 7050  TQRMNORRQHMORPCDEIJAH00802469        1.0        1.0  2024.0
#
#       trimestre_x  region_x mas_500_x  aglomerado_x  pondera_x  iv1  ...  \
# 0             1.0       1.0         S          32.0     1299.0  2.0  ...
# ...

# %%
datos.to_excel("datostp4.xlsx")

# %% [markdown]
# ### EJERCICIO 3
# Limpien la base de datos tomando criterios que hagan sentido.
# Explicar cualquier decisión como el tratamiento de valores faltantes (missing values), extremos (outliers), o variables categóricas.
# Justifique sus decisiones.

# %%
### Manejo de valores faltantes
num_columns = datos.select_dtypes(include=['float64', 'int64']).columns
cat_columns = datos.select_dtypes(include=['object']).columns

for col in num_columns:
    datos.loc[:, col] = datos[col].fillna(datos[col].median())  # Usamos la mediana

for col in cat_columns:
    datos.loc[:, col] = datos[col].fillna(datos[col].mode()[0])  # Usamos la moda

### Detección y tratamiento de outliers usando el rango intercuartílico (IQR)

datos[num_columns] = datos[num_columns].astype(float)

# Detección y tratamiento de outliers usando el rango intercuartílico (IQR)
for col in num_columns:
    # Calcular el IQR (Q3 - Q1)
    Q1 = datos[col].quantile(0.25)
    Q3 = datos[col].quantile(0.75)
    IQR = Q3 - Q1

    # Definir los límites para detectar outliers
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Reemplazar outliers con el límite inferior o superior usando .loc
    datos.loc[datos[col] < lower_bound, col] = lower_bound
    datos.loc[datos[col] > upper_bound, col] = upper_bound

df_limpio = datos
df_limpio

# Calcular el porcentaje de datos faltantes por columna
faltantes_porcentaje = df_limpio.isnull().mean()

# Identificar columnas con más del 50% de datos faltantes
columnas_a_eliminar = faltantes_porcentaje[faltantes_porcentaje > 0.5].index

# Eliminar las columnas
df_limpio1 = df_limpio.drop(columns=columnas_a_eliminar)
df_limpio1
# Out:
#                              CODUSU  nro_hogar  realizada  ano4_x  \
# 0                          125098.0        1.0        1.0  2004.0
# 1                          125397.0        1.0        1.0  2004.0
# 2                          125515.0        1.0        1.0  2004.0
# 3                          125558.0        1.0        1.0  2004.0
# 4                          125558.0        1.0        1.0  2004.0
# ...                             ...        ...        ...     ...
# 7046  TQRMNOQQWHKMOQCDEIJAH00861732        1.0        1.0  2024.0
# 7047  TQRMNOSXRHKMNMCDEIJAH00861733        1.0        1.0  2024.0
# 7048  TQRMNORRQHMORPCDEIJAH00802469        1.0        1.0  2024.0
# 7049  TQRMNORRQHMORPCDEIJAH00802469        1.0        1.0  2024.0
# 7050  TQRMNORRQHMORPCDEIJAH00802469        1.0        1.0  2024.0
#
#       trimestre_x  region_x mas_500_x  aglomerado_x  pondera_x  iv1  ...  \
# 0             1.0       1.0         S          33.0     1299.0  2.0  ...
# ...

# %%
df_limpio1.to_excel("dflimpioTP4.xlsx")

# %% [markdown]
# ### EJERCICO 4
# Construya variables (mínimo 3) que no estén en la base pero que sean relevantes para predecir
# individuos desocupados (por ejemplo, la proporción de personas que trabajan en el hogar).

# %%
# Revisar los nombres de las columnas y las primeras filas del DataFrame para identificar variables útiles
datos.columns.tolist(), datos.head()
# Out:
# (['CODUSU',
#   'nro_hogar',
#   'realizada',
#   'ano4_x',
#   'trimestre_x',
#   'region_x',
#   'mas_500_x',
#   'aglomerado_x',
#   'pondera_x',
#   'iv1',
#   'iv1_esp',
#   'iv2',
#   'iv3',
#   'iv3_esp',
#   'iv4',
#   'iv5',
#   'iv6',
#   'iv7',
#   'iv7_esp',
#   'iv8',
#   'iv9',
#   'iv10',
#   'iv11',
#   'iv12_1',
#   'iv12_2',
#   'iv12_3',
#   'ii1',
#   'ii2',
#   'ii3',
#   'ii3_1',
#   'ii4_1',
#   'ii4_2',
#   'ii4_3',
#   'ii5',
#   'ii5_1',
#   'ii6',
#   'ii6_1',
#   'ii7',
#   'ii7_esp',
#   'ii8',
#   'ii8_esp',
#   'ii9',
#   'v1',
#   'v2',
#   'v21',
#   'v22',
#   'v3',
#   'v4',
#   'v5',
#   'v6',
#   'v7',
#   'v8',
#   'v9',
#   'v10',
#   'v11',
#   'v12',
#   'v13',
#   'v14',
#   'v15',
#   'v16',
#   'v17',
#   'v18',
#   'v19_a',
#   'v19_b',
#   'IX_Tot',
#   'IX_Men10',
#   'IX_Mayeq10',
#   'itf_x',
#   'decifr_x',
#   'idecifr_x',
#   'rdecifr_x',
#   'gdecifr_x',
#   'pdecifr_x',
#   'adecifr_x',
#   'ipcf_x',
#   'deccfr_x',
# ...

# %%
# cantidad de ingreso por persona en el hogar
# itf_x: Monto de ingreso total familiar
# IX_Tot: cantidad de personas x hogar
variablenueva1 = df_limpio1['itf_x'] / df_limpio1['IX_Tot']
variablenueva1

#proporcion de subsidios recibidos sobre el ingreso total del hogar
#v5_m: Monto del ingreso por subsidio o ayuda social (en dinero) del gobierno, iglesias, etc.
# itf_x: Monto de ingreso total familiar
variablenueva2 = (df_limpio1['v5_m'] / df_limpio1['itf_x']) * 100
variablenueva2 ## me da 0
# Out:
# 0       0.0
# 1       NaN
# 2       0.0
# 3       0.0
# 4       0.0
#        ...
# 7046    NaN
# 7047    0.0
# 7048    0.0
# 7049    0.0
# 7050    0.0
# Length: 14698, dtype: float64

# %% [markdown]
# ### EJERCICIO 5
# Presenten estadísticas descriptivas de tres variables de la encuesta de hogar que ustedes creen que pueden ser relevantes para predecir la desocupación. Comenten las estadísticas obtenidas.

# %%
# Selección de las variables relevantes
# Ingreso per cápita familiar
# Régimen de tenencia de la vivienda
# Ingresos de la ocupación principal de los asalariados: ¿Cuánto cobró por ese mes por estos conceptos? Monto total de sueldos / jornales, salario familiar, horas extras, otras boni caciones habituales y tickets, vales o similares
variables_interes = ['ipcf_x', 'ii7', 'pp08d1']

# Generar estadísticas descriptivas
estadisticas_descriptivas = df_limpio[variables_interes].describe()
print(estadisticas_descriptivas)
# Out:
#               ipcf_x           ii7        pp08d1
# count   14698.000000  14698.000000  14698.000000
# mean    32171.559720      1.872840     89.113009
# std     55096.277338      1.492841    156.143072
# min         0.000000      0.000000     -9.000000
# 25%        58.000000      1.000000      0.000000
# 50%       266.666667      1.000000      0.000000
# 75%     55555.560000      3.000000    150.000000
# max    138801.900000      6.000000    375.000000

# %% [markdown]
# ## PARTE 2:  CLASIFICACIÓN Y REGULARIZACIÓN

# %% [markdown]
# ### EJERCICIO 1
# Para cada año, partan la base respondieron en una base de prueba y una de entrenamiento (X_train, y_train, X_test, y_test) utilizando el comando train_test_split. La base de entrenamiento debe comprender el 70% de los datos, y la semilla a utilizar (random state instance) debe ser 101.
# Establezca a desocupado como su variable dependiente en la base de entrenamiento (vector y).
# El resto de las variables serán las variables independientes (matriz X). Recuerden agregar la columna de unos (1).

# %%
# Crear la base con las observaciones donde respondieron la pregunta sobre condición de actividad (ESTADO != 0)
respondieron = df_limpio1[df_limpio1['estado'] != 0]
respondieron
# Out:
#                              CODUSU  nro_hogar  realizada  ano4_x  \
# 0                          125098.0        1.0        1.0  2004.0
# 1                          125397.0        1.0        1.0  2004.0
# 2                          125515.0        1.0        1.0  2004.0
# 3                          125558.0        1.0        1.0  2004.0
# 4                          125558.0        1.0        1.0  2004.0
# ...                             ...        ...        ...     ...
# 7046  TQRMNOQQWHKMOQCDEIJAH00861732        1.0        1.0  2024.0
# 7047  TQRMNOSXRHKMNMCDEIJAH00861733        1.0        1.0  2024.0
# 7048  TQRMNORRQHMORPCDEIJAH00802469        1.0        1.0  2024.0
# 7049  TQRMNORRQHMORPCDEIJAH00802469        1.0        1.0  2024.0
# 7050  TQRMNORRQHMORPCDEIJAH00802469        1.0        1.0  2024.0
#
#       trimestre_x  region_x mas_500_x  aglomerado_x  pondera_x  iv1  ...  \
# 0             1.0       1.0         S          33.0     1299.0  2.0  ...
# ...

# %%
respondieron.loc[:,'desocupado'] = respondieron['estado'].apply(lambda x: 1 if x == 2 else 0) #desocupado: estado == 2

#contamos cuantas personas estan desocupadas en 2004 y 2024
desocupados_2004 = respondieron[respondieron['ano4_x'] == 2004]['desocupado'].sum()
desocupados_2024 = respondieron[respondieron['ano4_x'] == 2024]['desocupado'].sum()

print(f'Cantidad de personas desocupadas en 2004: {desocupados_2004}')
print(f'Cantidad de personas desocupadas en 2024: {desocupados_2024}')
# Out:
# Cantidad de personas desocupadas en 2004: 528
# Cantidad de personas desocupadas en 2024: 311
# C:\Users\belug\AppData\Local\Temp\ipykernel_19308\1391351847.py:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   respondieron.loc[:,'desocupado'] = respondieron['estado'].apply(lambda x: 1 if x == 2 else 0) #desocupado: estado == 2
# C:\Users\belug\AppData\Local\Temp\ipykernel_19308\1391351847.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
# Selección de las variables relevantes
# Ingreso per cápita familiar
# Régimen de tenencia de la vivienda
# Monto del ingreso por subsidio o ayuda social (en dinero) del gobierno, iglesias, etc.
variables_interes = ['ipcf_x', 'ii7', 'v5_m']

# Generar estadísticas descriptivas
estadisticas_descriptivas = df_limpio[variables_interes].describe()
print(estadisticas_descriptivas)
# Out:
#               ipcf_x           ii7     v5_m
# count   14698.000000  14698.000000  14698.0
# mean    32171.559720      1.872840      0.0
# std     55096.277338      1.492841      0.0
# min         0.000000      0.000000      0.0
# 25%        58.000000      1.000000      0.0
# 50%       266.666667      1.000000      0.0
# 75%     55555.560000      3.000000      0.0
# max    138801.900000      6.000000      0.0

# %%
# Separar los datos para 2004 y 2024

# Filtrar datos del año 2004
df_2004l = respondieron[respondieron['ano4_x'] == 2004]

# Filtrar datos del año 2024
df_2024l = respondieron[respondieron['ano4_x'] == 2024]

# Confirmar que los dataframes fueron creados correctamente
print(f"Datos 2004: {df_2004l.shape}")
print(f"Datos 2024: {df_2024l.shape}")

# Revisar las primeras filas de los dataframes para confirmar los años
#print(df_2004l.head())
#print(df_2024l.head())

df_2004l
df_2024l
# Out:
# Datos 2004: (7637, 264)
# Datos 2024: (7010, 264)
#                              CODUSU  nro_hogar  realizada  ano4_x  \
# 0     TQRMNOSPRHLMNNCDEIIAD00854888        1.0        1.0  2024.0
# 1     TQRMNOSPTHLMNNCDEIIAD00854889        1.0        1.0  2024.0
# 2     TQRMNOSPTHLMNNCDEIIAD00854889        1.0        1.0  2024.0
# 3     TQRMNOSPTHLMNNCDEIIAD00854889        1.0        1.0  2024.0
# 4     TQRMNOSPTHLMNNCDEIIAD00854889        1.0        1.0  2024.0
# ...                             ...        ...        ...     ...
# 7046  TQRMNOQQWHKMOQCDEIJAH00861732        1.0        1.0  2024.0
# 7047  TQRMNOSXRHKMNMCDEIJAH00861733        1.0        1.0  2024.0
# 7048  TQRMNORRQHMORPCDEIJAH00802469        1.0        1.0  2024.0
# 7049  TQRMNORRQHMORPCDEIJAH00802469        1.0        1.0  2024.0
# 7050  TQRMNORRQHMORPCDEIJAH00802469        1.0        1.0  2024.0
#
#       trimestre_x  region_x mas_500_x  aglomerado_x  pondera_x  iv1  ...  \
# ...

# %%
#CODIGO 2004
import pandas as pd
from sklearn.model_selection import train_test_split
import numpy as np

# Codificar variables categóricas
# Identificar columnas categóricas y convertirlas a 'category' si están codificadas numéricamente
categorical_columns = ['v5', 'v6', 'v13', 'ii7']  # Reemplaza con las columnas categóricas relevantes
respondieron[categorical_columns] = respondieron[categorical_columns].astype('category')

# Generar variables dummy, excluyendo variables deZpendientes del estado 'desocupado'
df_encoded = pd.get_dummies(respondieron, drop_first=True)

# Codificar variables categóricas
# df_encoded = pd.get_dummies(respondieron, drop_first=True)
#df_encoded

# Filtrar los datos para el año 2004
df_2004l = df_encoded[df_encoded['ano4_x'] == 2004]

# Matriz de variables independientes (sin 'desocupado')
X_2004 = df_2004l.drop(columns=['desocupado', 'ano4_x'])

# Variable dependiente ('desocupado')
y_2004 = df_2004l['desocupado']

# Dividir en entrenamiento y prueba (70% entrenamiento, 30% prueba) con random_state=101
X_train_2004, X_test_2004, y_train_2004, y_test_2004 = train_test_split(X_2004, y_2004, test_size=0.3, random_state=101)

# Agregar una columna de unos a las matrices de entrenamiento y prueba
X_train_2004 = np.concatenate([np.ones((X_train_2004.shape[0], 1)), X_train_2004], axis=1)
X_test_2004 = np.concatenate([np.ones((X_test_2004.shape[0], 1)), X_test_2004], axis=1)

print("Año 2004:")
print(f"Tamaño de X_train: {X_train_2004.shape}")
print(f"Tamaño de X_test: {X_test_2004.shape}")
print(f"Tamaño de y_train: {y_train_2004.shape}")
print(f"Tamaño de y_test: {y_test_2004.shape}")
# Out:
# C:\Users\belug\AppData\Local\Temp\ipykernel_19308\3057489576.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   respondieron[categorical_columns] = respondieron[categorical_columns].astype('category')
# Año 2004:
# Tamaño de X_train: (5345, 11017)
# Tamaño de X_test: (2292, 11017)
# Tamaño de y_train: (5345,)
# Tamaño de y_test: (2292,)

# %%
#CODIGO 2024
import pandas as pd
from sklearn.model_selection import train_test_split
import numpy as np

# Codificar variables categóricas
# Identificar columnas categóricas y convertirlas a 'category' si están codificadas numéricamente
categorical_columns = ['v5', 'v6', 'v13', 'ii7']  # Reemplaza con las columnas categóricas relevantes
respondieron[categorical_columns] = respondieron[categorical_columns].astype('category')


# Generar variables dummy, excluyendo variables dependientes del estado 'desocupado'
df_encoded = pd.get_dummies(respondieron, drop_first=True)

# Filtrar los datos para el año 2004
df_2024l = df_encoded[df_encoded['ano4_x'] == 2024]

# Matriz de variables independientes (sin 'desocupado')
X_2024 = df_2024l.drop(columns=['desocupado', 'ano4_x'])

# Variable dependiente ('desocupado')
y_2024 = df_2024l['desocupado']

# Dividir en entrenamiento y prueba (70% entrenamiento, 30% prueba) con random_state=101
X_train_2024, X_test_2024, y_train_2024, y_test_2024 = train_test_split(X_2024, y_2024, test_size=0.3, random_state=101)

# Agregar una columna de unos a las matrices de entrenamiento y prueba
X_train_2024 = np.concatenate([np.ones((X_train_2024.shape[0], 1)), X_train_2024], axis=1)
X_test_2024 = np.concatenate([np.ones((X_test_2024.shape[0], 1)), X_test_2024], axis=1)

print("Año 2024:")
print(f"Tamaño de X_train: {X_train_2024.shape}")
print(f"Tamaño de X_test: {X_test_2024.shape}")
print(f"Tamaño de y_train: {y_train_2024.shape}")
print(f"Tamaño de y_test: {y_test_2024.shape}")
# Out:
# C:\Users\belug\AppData\Local\Temp\ipykernel_19308\3913115314.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   respondieron[categorical_columns] = respondieron[categorical_columns].astype('category')
# Año 2024:
# Tamaño de X_train: (4907, 11017)
# Tamaño de X_test: (2103, 11017)
# Tamaño de y_train: (4907,)
# Tamaño de y_test: (2103,)

# %% [markdown]
# ### EJERCICIO 2 Y 3
# Realizados en el informe

# %% [markdown]
# ### EJERCICIO 4
# Para regresión logística, implementen la penalidad, L1 como la de LASSO y L2 como la de Ridge con λ = 1 (como en la Tutorial 10), usando la opción penalty y reporten la matriz de confusión, la curva ROC, los valores de AUC y de Accuracy para cada año.1
# ¿Cómo cambiaron los resultados con respecto al TP3? ¿La performance de regresión logística con regularización es mejor o peor?

# %%
# REG LOGISTICA 2004
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, roc_curve, roc_auc_score, accuracy_score
import matplotlib.pyplot as plt

# Modelo de regresión logística con penalización L1 Lasso
model_l1 = LogisticRegression(penalty='l1', solver='liblinear', C=1)
model_l1.fit(X_train_2004, y_train_2004)
y_pred_l1 = model_l1.predict(X_test_2004)
y_prob_l1 = model_l1.predict_proba(X_test_2004)[:, 1]

# Modelo de regresión logística con penalización L2 Ridge
model_l2 = LogisticRegression(penalty='l2', solver='liblinear', C=1)
model_l2.fit(X_train_2004, y_train_2004)
y_pred_l2 = model_l2.predict(X_test_2004)
y_prob_l2 = model_l2.predict_proba(X_test_2004)[:, 1]

# Métricas para L1
confusion_l1 = confusion_matrix(y_test_2004, y_pred_l1)
roc_auc_l1 = roc_auc_score(y_test_2004, y_prob_l1)
accuracy_l1 = accuracy_score(y_test_2004, y_pred_l1)

# Métricas para L2
confusion_l2 = confusion_matrix(y_test_2004, y_pred_l2)
roc_auc_l2 = roc_auc_score(y_test_2004, y_prob_l2)
accuracy_l2 = accuracy_score(y_test_2004, y_pred_l2)

# Imprimir resultados
print("Penalización L1:")
print(f"Matriz de confusión:\n{confusion_l1}")
print(f"AUC: {roc_auc_l1:.2f}")
print(f"Accuracy: {accuracy_l1:.2f}\n")

print("Penalización L2:")
print(f"Matriz de confusión:\n{confusion_l2}")
print(f"AUC: {roc_auc_l2:.2f}")
print(f"Accuracy: {accuracy_l2:.2f}\n")

# Generar curvas ROC
fpr_l1, tpr_l1, _ = roc_curve(y_test_2004, y_prob_l1)
fpr_l2, tpr_l2, _ = roc_curve(y_test_2004, y_prob_l2)

plt.figure(figsize=(8, 6))
plt.plot(fpr_l1, tpr_l1, label=f'L1 (AUC = {roc_auc_l1:.2f})')
plt.plot(fpr_l2, tpr_l2, label=f'L2 (AUC = {roc_auc_l2:.2f})')
plt.plot([0, 1], [0, 1], 'k--', label='Random')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Curva ROC')
plt.legend()
plt.show()
# Out:
# Penalización L1:
# Matriz de confusión:
# [[2133    0]
#  [   0  159]]
# AUC: 1.00
# Accuracy: 1.00
#
# Penalización L2:
# Matriz de confusión:
# [[2132    1]
#  [   6  153]]
# AUC: 1.00
# Accuracy: 1.00

# %%
# REG LOGISTICA 2024
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, roc_curve, roc_auc_score, accuracy_score
import matplotlib.pyplot as plt

# Modelo de regresión logística con penalización L1
model_l1 = LogisticRegression(penalty='l1', solver='liblinear', C=1)
model_l1.fit(X_train_2024, y_train_2024)
y_pred_l1 = model_l1.predict(X_test_2024)
y_prob_l1 = model_l1.predict_proba(X_test_2024)[:, 1]

# Modelo de regresión logística con penalización L2
model_l2 = LogisticRegression(penalty='l2', solver='liblinear', C=1)
model_l2.fit(X_train_2024, y_train_2024)
y_pred_l2 = model_l2.predict(X_test_2024)
y_prob_l2 = model_l2.predict_proba(X_test_2024)[:, 1]

# Métricas para L1
confusion_l1 = confusion_matrix(y_test_2024, y_pred_l1)
roc_auc_l1 = roc_auc_score(y_test_2024, y_prob_l1)
accuracy_l1 = accuracy_score(y_test_2024, y_pred_l1)

# Métricas para L2
confusion_l2 = confusion_matrix(y_test_2024, y_pred_l2)
roc_auc_l2 = roc_auc_score(y_test_2024, y_prob_l2)
accuracy_l2 = accuracy_score(y_test_2024, y_pred_l2)

# Imprimir resultados
print("Penalización L1:")
print(f"Matriz de confusión:\n{confusion_l1}")
print(f"AUC: {roc_auc_l1:.2f}")
print(f"Accuracy: {accuracy_l1:.2f}\n")

print("Penalización L2:")
print(f"Matriz de confusión:\n{confusion_l2}")
print(f"AUC: {roc_auc_l2:.2f}")
print(f"Accuracy: {accuracy_l2:.2f}\n")

# Generar curvas ROC
fpr_l1, tpr_l1, _ = roc_curve(y_test_2024, y_prob_l1)
fpr_l2, tpr_l2, _ = roc_curve(y_test_2024, y_prob_l2)

plt.figure(figsize=(8, 6))
plt.plot(fpr_l1, tpr_l1, label=f'L1 (AUC = {roc_auc_l1:.2f})')
plt.plot(fpr_l2, tpr_l2, label=f'L2 (AUC = {roc_auc_l2:.2f})')
plt.plot([0, 1], [0, 1], 'k--', label='Random')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Curva ROC')
plt.legend()
plt.show()
# Out:
# Penalización L1:
# Matriz de confusión:
# [[2008    1]
#  [   0   94]]
# AUC: 1.00
# Accuracy: 1.00
#
# Penalización L2:
# Matriz de confusión:
# [[2009    0]
#  [  94    0]]
# AUC: 0.85
# Accuracy: 0.96

# %% [markdown]
# ### EJERCICIO 5
# Realicen un barrido en λ = 10n con n ∈ {−5, −4, −3 ..., +4, +5} y utilicen 10-fold CV para elegir el λ óptimo en regresión logística con Ridge y con LASSO.
# ¿Qué λ seleccionó en cada caso? Usando la librería de seaborn, generen box plot mostrando la distribución del error de predicción para cada λ. Cada box debe corresponder a un valor de λ y contener como observaciones el error medio de validación (MSE) para cada partición.
# Además, para la regularización LASSO, generen un line plot del promedio de la proporción de variables ignoradas por el modelo en función de λ (como vieron en el tutorial 10), es decir la proporción de variables para las cuales el coeficiente asociado es cero

# %%
import numpy as np

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV

# %%
#PARTE 1
#Realicen un barrido en = 10^n λ con n ∈ {−5, −4, −3 ..., +4, +5} y utilicen 10-fold CV para elegir el λ óptimo en regresión logística con Ridge y con LASSO. 

#definimos el rango de λ (C en scikit-learn es inversamente proporcional a λ: \( \lambda = 1 / C \))
param_grid = {'C': [10**n for n in range(-5, 6)]}  # \( n \in \{-5, ..., +5\} \)
 
#AÑO 2004

#ridge (L2) para 2004
ridge_logistic_2004 = LogisticRegression(penalty='l2', solver='liblinear', max_iter=1000)
grid_search_ridge_2004 = GridSearchCV(ridge_logistic_2004, param_grid, cv=10, scoring='roc_auc')  # ROC-AUC como métrica
grid_search_ridge_2004.fit(X_train_2004_sample, y_train_2004_sample)
best_ridge_C_2004 = grid_search_ridge_2004.best_params_['C']

#LASSO (L1) para 2004
lasso_logistic_2004 = LogisticRegression(penalty='l1', solver='liblinear', max_iter=1000)
grid_search_lasso_2004 = GridSearchCV(lasso_logistic_2004, param_grid, cv=10, scoring='roc_auc')  # ROC-AUC como métrica
grid_search_lasso_2004.fit(X_train_2004_sample, y_train_2004_sample)
best_lasso_C_2004 = grid_search_lasso_2004.best_params_['C']

# %%
#AÑO 2024

#ridge (L2) para 2024
ridge_logistic_2024 = LogisticRegression(penalty='l2', solver='liblinear', max_iter=1000)
grid_search_ridge_2024 = GridSearchCV(ridge_logistic_2024, param_grid, cv=10, scoring='roc_auc')  # ROC-AUC como métrica
grid_search_ridge_2024.fit(X_train_2024_sample, y_train_2024_sample)
best_ridge_C_2024 = grid_search_ridge_2024.best_params_['C']

#LASSO (L1) para 2024
lasso_logistic_2024 = LogisticRegression(penalty='l1', solver='liblinear', max_iter=1000)
grid_search_lasso_2024 = GridSearchCV(lasso_logistic_2024, param_grid, cv=10, scoring='roc_auc')  # ROC-AUC como métrica
grid_search_lasso_2024.fit(X_train_2024_sample, y_train_2024_sample)
best_lasso_C_2024 = grid_search_lasso_2024.best_params_['C']

# %%
# Imprimir los mejores valores de λ para cada caso
print(f"Mejor λ (Ridge) para 2004: {1/best_ridge_C_2004}")
print(f"Mejor λ (LASSO) para 2004: {1/best_lasso_C_2004}")
print(f"Mejor λ (Ridge) para 2024: {1/best_ridge_C_2024}")
print(f"Mejor λ (LASSO) para 2024: {1/best_lasso_C_2024}")
# Out:
# Mejor λ (Ridge) para 2004: 0.001
# Mejor λ (LASSO) para 2004: 1.0
# Mejor λ (Ridge) para 2024: 0.0001
# Mejor λ (LASSO) para 2024: 0.1

# %%
#PARTE 2
#Usando la librería de seaborn, generen box plot mostrando la distribución del error de predicción para cada λ. 
# Cada box debe corresponder a un valor de λ y contener como observaciones el error medio de validación (MSE) para cada partición.

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_squared_error

#configuracion de valores de λ (alpha)
alphas = [10**n for n in range(-5, 6)]  # Barrido de valores entre 10^-5 y 10^5
mse_scores = []  # Para almacenar los MSE

#calculo del MSE:
#iterar sobre cada valor de α
for alpha in alphas:
    ridge = Ridge(alpha=alpha)
    #validación cruzada (10-fold CV)
    scores = cross_val_score(ridge, X_train_2004_sample, y_train_2004_sample, #se usa cross_val_score para obtener los errores de validación (negativos), que son convertidos a positivos.
                             cv=10, scoring='neg_mean_squared_error')
    #guardamos resultados como MSE positivos
    mse_scores.extend([(-score, np.log10(alpha)) for score in scores])

#convertimos los resultados a un DataFrame
mse_df = pd.DataFrame(mse_scores, columns=['MSE', 'log10_lambda'])

#creamos el boxplot
plt.figure(figsize=(10, 6))
sns.boxplot(data=mse_df, x='log10_lambda', y='MSE', palette='Blues')
plt.title('Distribución del Error de Validación para cada log10(λ)', fontsize=14)
plt.xlabel('log10(λ)', fontsize=12)
plt.ylabel('Mean Squared Error (MSE)', fontsize=12)
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

#el gráfico muestra la dispersión del MSE para cada 𝜆 en escala logarítmica. 
#esto ayuda a identificar el rango de 𝜆 donde los errores son menores y más estables.

#Análisis de resultados del grafico:

# - valores bajos de λ (menos regularización): En valores como log10(𝜆) = −5, −4 se observa un MSE bajo y estable (caja pequeña y mediana cerca del extremo inferior del eje Y).
#esto indica que el modelo se ajusta bien a los datos sin introducir un nivel de penalización significativo.

# - valores intermedios de λ:A medida que λ aumenta (log10(𝜆) = −2,−1,0 el MSE sigue siendo bajo, pero la dispersión puede aumentar.Estos valores de 
#λ suelen representar un equilibrio entre ajuste y regularización.

# - valores altos de λ (regularización fuerte): Para log10(𝜆)= 4,5, el MSE aumenta significativamente.
#esto ocurre porque una regularización fuerte penaliza demasiado los coeficientes del modelo, lo que genera un subajuste (underfitting).

#mejor rango de λ: Según el gráfico, el rango óptimo de λ parece estar entre −2 ≤ log10(𝜆) ≤ 0, ya que aquí el MSE es más bajo y tiene menor variabilidad.
# Out:
# C:\Users\belug\anaconda3\Lib\site-packages\sklearn\linear_model\_ridge.py:241: LinAlgWarning: Ill-conditioned matrix (rcond=5.66524e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# C:\Users\belug\anaconda3\Lib\site-packages\sklearn\linear_model\_ridge.py:241: LinAlgWarning: Ill-conditioned matrix (rcond=7.27796e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# C:\Users\belug\anaconda3\Lib\site-packages\sklearn\linear_model\_ridge.py:241: LinAlgWarning: Ill-conditioned matrix (rcond=5.32734e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# C:\Users\belug\anaconda3\Lib\site-packages\sklearn\linear_model\_ridge.py:241: LinAlgWarning: Ill-conditioned matrix (rcond=6.12871e-17): result may not be accurate.
#   dual_coef = linalg.solve(K, y, assume_a="pos", overwrite_a=False)
# ...

# %%
#PARTE 3
#Además, para la regularización LASSO, generen un line plot del promedio de la proporción de variables ignoradas por el modelo en función de λ (como vieron en el tutorial 10), 
# es decir la proporción de variables para las cuales el coeficiente asociado es cero

from sklearn.linear_model import Lasso

#valores de λ (alpha) para el barrido
alphas = [10**n for n in range(-5, 6)]  # De 10^-5 a 10^5
proportion_zero_coefs = []  # Para almacenar la proporción de coeficientes cero

#iteramos sobre los valores de α
for alpha in alphas:
    lasso = Lasso(alpha=alpha, max_iter=10000)
    lasso.fit(X_train_2004_sample, y_train_2004_sample)
    # Calcular proporción de coeficientes en cero
    num_zero_coefs = np.sum(lasso.coef_ == 0) #Contamos los coeficientes del modelo que son exactamente cero
    proportion_zero_coefs.append(num_zero_coefs / len(lasso.coef_)) #Dividimos el número de coeficientes cero por el total de coeficientes.

#creamos un DataFrame con los resultados
lasso_zero_df = pd.DataFrame({
    'log10_lambda': np.log10(alphas),
    'proportion_zero_coefs': proportion_zero_coefs
})

#generamos el line plot
#usamos un line plot para visualizar cómo la proporción de variables ignoradas cambia con log10(𝜆).
plt.figure(figsize=(10, 6))
sns.lineplot(data=lasso_zero_df, x='log10_lambda', y='proportion_zero_coefs', marker='o', color='blue')
plt.title('Proporción de Variables Ignoradas vs log10(λ)', fontsize=14)
plt.xlabel('log10(λ)', fontsize=12)
plt.ylabel('Proporción de Coeficientes Cero', fontsize=12)
plt.grid(axis='both', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

#el gráfico muestra cómo la regularización LASSO elimina variables al aumentar 𝜆
#a valores bajos de λ, pocos coeficientes son cero; a valores altos, la mayoría de las variables son ignoradas. 

#GRAFICO:
# - el gráfico demuestra cómo LASSO realiza la selección de variables de forma eficiente al incrementar 𝜆 Un valor de 𝜆 demasiado alto elimina demasiadas variables, 
# - reduciendo la capacidad predictiva del modelo. Sin embargo, un valor moderado de λ puede encontrar un balance adecuado entre simplicidad del modelo y desempeño.
#Para este caso, el punto óptimo estaría en el rango donde la proporción de coeficientes cero comienza a estabilizarse sin alcanzar el 100%, permitiendo seleccionar un conjunto relevante de predictores.
# Out:
# C:\Users\belug\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.899e-02, tolerance: 1.025e-02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\belug\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.643e-01, tolerance: 1.025e-02
#   model = cd_fast.enet_coordinate_descent(
# ...

# %% [markdown]
# ### EJERCICIO 6
# En el caso del valor óptimo de λ para LASSO encontrado en el inciso anterior, ¿qué variables fueron descartadas? ¿Son las que hubieran esperado? ¿Tiene relación con lo que respondieron en el inciso 1 de la Parte I?

# %%
# Definir los valores óptimos de lambda para cada año
lambdas_lasso = {'2004': 0.001, '2024': 1.0}

# Crear un diccionario para almacenar resultados
resultados = {}

for year, lambda_opt in lambdas_lasso.items():
    # Crear y ajustar el modelo LASSO
    lasso_model = Lasso(alpha=lambda_opt, max_iter=10000)
    
    # Seleccionar conjuntos de entrenamiento según el año
    X_train = X_train_2004_sample if year == '2004' else X_train_2024_sample
    y_train = y_train_2004 if year == '2004' else y_train_2024
    
    # Recortar X_train e y_train al tamaño mínimo para asegurar compatibilidad
    min_samples = min(len(X_train), len(y_train))
    X_train = X_train[:min_samples]
    y_train = y_train[:min_samples]
    
    # Ajustar el modelo
    lasso_model.fit(X_train, y_train)
    
    # Crear DataFrame con los coeficientes
    coeficientes = pd.DataFrame({
        'Variable': X_train.columns if isinstance(X_train, pd.DataFrame) else [f'Var_{i}' for i in range(X_train.shape[1])],
        'Coeficiente': lasso_model.coef_
    })

    # Separar variables descartadas y relevantes
    variables_descartadas = coeficientes[coeficientes['Coeficiente'] == 0]['Variable'].tolist()
    variables_relevantes = coeficientes[coeficientes['Coeficiente'] != 0]['Variable'].tolist()
    
    # Guardar resultados en el diccionario
    resultados[year] = {
        'descartadas': len(variables_descartadas),
        'relevantes': len(variables_relevantes)
    }

# Imprimir resultados detallados para responder la consigna
for year, res in resultados.items():
    print(f"\n--- Resultados para el año {year} con λ óptimo {lambdas_lasso[year]} ---")
    print(f"Cantidad de variables descartadas (coeficientes = 0): {res['descartadas']}")
    print(f"Cantidad de variables relevantes (coeficientes ≠ 0): {res['relevantes']}")
# Out:
# --- Resultados para el año 2004 con λ óptimo 0.001 ---
# Cantidad de variables descartadas (coeficientes = 0): 10932
# Cantidad de variables relevantes (coeficientes ≠ 0): 85
#
# --- Resultados para el año 2024 con λ óptimo 1.0 ---
# Cantidad de variables descartadas (coeficientes = 0): 11008
# Cantidad de variables relevantes (coeficientes ≠ 0): 9

# %% [markdown]
# ### EJERCICIO 7
# Elijan alguno de los modelos de regresión logística donde hayan probado distintos parámetros de regularización y comenten: Compare los resultados de 2004 versus 2024, ¿qué método de regularización funcionó mejor: Ridge o LASSO? ¿LASSO hizo una selección distinta de predictores en 2004 versus 2024? Comenten mencionando el error cuadrático medio (MSE).

# %%
from sklearn.metrics import mean_squared_error

# Entrenar modelos Ridge y LASSO para 2004 y 2024

# Ridge 2004
ridge_log2004 = LogisticRegression(penalty='l2', solver='liblinear', max_iter=1000, C=best_ridge_C_2004)
ridge_log2004.fit(X_train_2004_sample, y_train_2004_sample)
y_pred_ridge2004 = ridge_log2004.predict(X_test_2004)  # Corrección: usar ridge_log2004
mse_ridge2004 = mean_squared_error(y_test_2004, y_pred_ridge2004)

# Lasso 2004
lasso_log2004 = LogisticRegression(penalty='l1', solver='liblinear', max_iter=1000, C=best_lasso_C_2004)
lasso_log2004.fit(X_train_2004_sample, y_train_2004_sample)
y_pred_lasso2004 = lasso_log2004.predict(X_test_2004)  # Corrección: usar lasso_log2004
mse_lasso2004 = mean_squared_error(y_test_2004, y_pred_lasso2004)

# Ridge 2024
ridge_log2024 = LogisticRegression(penalty='l2', solver='liblinear', max_iter=1000, C=best_ridge_C_2024)
ridge_log2024.fit(X_train_2024_sample, y_train_2024_sample)
y_pred_ridge2024 = ridge_log2024.predict(X_test_2024)  # Corrección: usar ridge_log2024
mse_ridge2024 = mean_squared_error(y_test_2024, y_pred_ridge2024)

# Lasso 2024
lasso_log2024 = LogisticRegression(penalty='l1', solver='liblinear', max_iter=1000, C=best_lasso_C_2024)
lasso_log2024.fit(X_train_2024_sample, y_train_2024_sample)
y_pred_lasso2024 = lasso_log2024.predict(X_test_2024)  # Corrección: usar lasso_log2024
mse_lasso2024 = mean_squared_error(y_test_2024, y_pred_lasso2024)

# Imprimir los resultados
print(f"MSE RIDGE 2004: {mse_ridge2004}")
print(f"MSE LASSO 2004: {mse_lasso2004}")
print(f"MSE RIDGE 2024: {mse_ridge2024}")
print(f"MSE LASSO 2024: {mse_lasso2024}")
# Out:
# MSE RIDGE 2004: 0.0008726003490401396
# MSE LASSO 2004: 0.0004363001745200698
# MSE RIDGE 2024: 0.03471231573941987
# MSE LASSO 2024: 0.0019020446980504042
